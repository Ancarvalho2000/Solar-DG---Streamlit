# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open(r'C:\Users\Utilizador\Desktop\Uni\Estágios\2025 - InnoWave\Solar DG\solar_data\Plant_1_Generation_Data.csv', encoding='utf-8') as f:
    print(f.readline())
# Out:
# DATE_TIME,PLANT_ID,SOURCE_KEY,DC_POWER,AC_POWER,DAILY_YIELD,TOTAL_YIELD

# %%
df1 = pd.read_csv(
    r'C:\Users\Utilizador\Desktop\Uni\Estágios\2025 - InnoWave\Solar DG\solar_data\Plant_1_Generation_Data.csv',
    encoding='utf-8',
    engine='python',
    index_col='DATE_TIME'
)

# %%
df2 = pd.read_csv(
    r'C:\Users\Utilizador\Desktop\Uni\Estágios\2025 - InnoWave\Solar DG\solar_data\Plant_1_Weather_Sensor_Data.csv',
    encoding='utf-8',
    engine='python',
    index_col='DATE_TIME'
)

# %%
# Plant_1_Generation_Data.csv
df1.head()
# Out:
#                   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# DATE_TIME
# 15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0          0.0
#
#                   TOTAL_YIELD
# DATE_TIME
# 15-05-2020 00:00    6259559.0
# 15-05-2020 00:00    6183645.0
# 15-05-2020 00:00    6987759.0
# 15-05-2020 00:00    7602960.0
# 15-05-2020 00:00    7158964.0

# %%
# Plant_1_Weather_Sensor_Data.csv
df2.head()
# Out:
#                      PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-05-15 00:00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 2020-05-15 00:15:00   4135001  HmiyD2TTLFNqkNe            25.084589
# 2020-05-15 00:30:00   4135001  HmiyD2TTLFNqkNe            24.935753
# 2020-05-15 00:45:00   4135001  HmiyD2TTLFNqkNe            24.846130
# 2020-05-15 01:00:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#                      MODULE_TEMPERATURE  IRRADIATION
# DATE_TIME
# 2020-05-15 00:00:00           22.857507          0.0
# 2020-05-15 00:15:00           22.761668          0.0
# 2020-05-15 00:30:00           22.592306          0.0
# 2020-05-15 00:45:00           22.360852          0.0
# 2020-05-15 01:00:00           22.165423          0.0

# %%
df1.tail()
# Out:
#                   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# DATE_TIME
# 17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0     5967.000
# 17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0     5147.625
# 17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0     5819.000
# 17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0     5817.000
# 17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0     5910.000
#
#                   TOTAL_YIELD
# DATE_TIME
# 17-06-2020 23:45    7287002.0
# 17-06-2020 23:45    7028601.0
# 17-06-2020 23:45    7251204.0
# 17-06-2020 23:45    6583369.0
# 17-06-2020 23:45    7363272.0

# %%
df2.tail()
# Out:
#                      PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# DATE_TIME
# 2020-06-17 22:45:00   4135001  HmiyD2TTLFNqkNe            22.150570
# 2020-06-17 23:00:00   4135001  HmiyD2TTLFNqkNe            22.129816
# 2020-06-17 23:15:00   4135001  HmiyD2TTLFNqkNe            22.008275
# 2020-06-17 23:30:00   4135001  HmiyD2TTLFNqkNe            21.969495
# 2020-06-17 23:45:00   4135001  HmiyD2TTLFNqkNe            21.909288
#
#                      MODULE_TEMPERATURE  IRRADIATION
# DATE_TIME
# 2020-06-17 22:45:00           21.480377          0.0
# 2020-06-17 23:00:00           21.389024          0.0
# 2020-06-17 23:15:00           20.709211          0.0
# 2020-06-17 23:30:00           20.734963          0.0
# 2020-06-17 23:45:00           20.427972          0.0

# %%
# Change df2 DATE_TIME format to match df1's
df2.index = pd.to_datetime(df2.index)

# %%
df2.index = df2.index.strftime('%d-%m-%Y %H:%M')

# %%
df2.head()
# Out:
#                   PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 15-05-2020 00:00   4135001  HmiyD2TTLFNqkNe            25.184316
# 15-05-2020 00:15   4135001  HmiyD2TTLFNqkNe            25.084589
# 15-05-2020 00:30   4135001  HmiyD2TTLFNqkNe            24.935753
# 15-05-2020 00:45   4135001  HmiyD2TTLFNqkNe            24.846130
# 15-05-2020 01:00   4135001  HmiyD2TTLFNqkNe            24.621525
#
#                   MODULE_TEMPERATURE  IRRADIATION
# 15-05-2020 00:00           22.857507          0.0
# 15-05-2020 00:15           22.761668          0.0
# 15-05-2020 00:30           22.592306          0.0
# 15-05-2020 00:45           22.360852          0.0
# 15-05-2020 01:00           22.165423          0.0

# %%
df1.head()
# Out:
#                   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# DATE_TIME
# 15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0          0.0
#
#                   TOTAL_YIELD
# DATE_TIME
# 15-05-2020 00:00    6259559.0
# 15-05-2020 00:00    6183645.0
# 15-05-2020 00:00    6987759.0
# 15-05-2020 00:00    7602960.0
# 15-05-2020 00:00    7158964.0

# %%
df1['DC_POWER'].plot(legend=True, figsize=(12,5))
df1['AC_POWER'].plot(legend=True)

# %%
df2_cleaned = df2.drop(columns=['PLANT_ID', 'SOURCE_KEY'])

# %%
df3 = df1.merge(df2_cleaned, left_index=True, right_index=True, how='left')

# %%
df3
# Out:
#                   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 01-06-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0   829.000000
# 01-06-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0   730.375000
# 01-06-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  VHMLBKoKgIrUVDU       0.0       0.0   759.500000
# 01-06-2020 00:00   4135001  WRmjgnKYAwPKWDb       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  YxYtjZvoooNbGkE       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  ZnxXDlPa8U1GXgE       0.0       0.0   767.750000
# 01-06-2020 00:00   4135001  ZoEaEvLYb1n2sOq       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  adLQvlD726eNBSB       0.0       0.0     0.000000
# ...

# %%
df3 = df3.dropna()

# %%
df3
# Out:
#                   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# 01-06-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0   829.000000
# 01-06-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0   730.375000
# 01-06-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  VHMLBKoKgIrUVDU       0.0       0.0   759.500000
# 01-06-2020 00:00   4135001  WRmjgnKYAwPKWDb       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  YxYtjZvoooNbGkE       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  ZnxXDlPa8U1GXgE       0.0       0.0   767.750000
# 01-06-2020 00:00   4135001  ZoEaEvLYb1n2sOq       0.0       0.0     0.000000
# 01-06-2020 00:00   4135001  adLQvlD726eNBSB       0.0       0.0     0.000000
# ...

# %%
df3['AMBIENT_TEMPERATURE'].plot(figsize=(12,8))

# %%
df2['AMBIENT_TEMPERATURE'].plot(figsize=(12,5))

# %%
plt.figure(figsize=(12,5))
plt.plot(df2.index, df2['AMBIENT_TEMPERATURE'], label='Ambient Temp')

plt.xticks(rotation=45)
plt.xlabel('Date Time')
plt.ylabel('Temperature (ºC)')
plt.title('Ambient Temperature Over Time')
plt.legend()
plt.tight_layout()

plt.show()

# %%
df1.head(25)
# Out:
#                   PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD  \
# DATE_TIME
# 15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  VHMLBKoKgIrUVDU       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  WRmjgnKYAwPKWDb       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  ZnxXDlPa8U1GXgE       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  ZoEaEvLYb1n2sOq       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  adLQvlD726eNBSB       0.0       0.0          0.0
# 15-05-2020 00:00   4135001  bvBOhCH3iADSZry       0.0       0.0          0.0
# ...
